# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, silhouette_samples
import numpy as np

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# <h3> 1) Load and prepare data </h3>

# %%
merged_table = pd.read_csv('merged_table.csv', parse_dates=['invoice_datetime'])

# %%
# Convert string 'Null' into null value
merged_table = merged_table.replace({'Null':None})

# %%
# Count number of null values in each column
merged_table.isnull().sum()
# Out:
# invoice_no               0
# product_id            8398
# quantity                 0
# unit_price               0
# total_sale               0
# customer_id         139315
# rating                   0
# review_count             0
# country                  0
# product_name             0
# product_type             0
# stock_code               0
# invoice_datetime         0
# day_of_week              0
# month                    0
# hour                     0
# year                     0
# quarter                  0
# invoice_date             0
# dtype: int64

# %%
# Drop rows with missing values and save as new df
commerce = merged_table.dropna()

# %%
commerce.head(2)
# Out:
#   invoice_no  product_id  quantity  unit_price  total_sale customer_id  \
# 0   78536597  B07GWKDLGT         4      496.95     1987.80       18011
# 1   78536597  B01MTLH408         4       39.99      159.96       18011
#
#    rating  review_count  country  \
# 0     4.6          1399  Germany
# 1     4.6           289  Germany
#
#                                         product_name product_type stock_code  \
# 0  Nikon D3500 W/ AF-P DX NIKKOR 18-55mm f/3.5-5....  dslr camera      21703
# 1  Manfrotto Element Aluminum 5-Section Monopod, ...  dslr camera      40001
#
#      invoice_datetime  day_of_week  month  hour  year  quarter invoice_date
# 0 2018-12-01 17:00:00            5     12    17  2018        4   2018-12-01
# 1 2018-12-01 17:00:00            5     12    17  2018        4   2018-12-01

# %% [markdown]
# <h3> 2) Feature selection </h3>

# %% [markdown]
# <h5> We want to use three features for k-means clustering: </h5>
#
# - recency: days since last purchase
# - frequency: number of orders per customer id
# - monetary: total revenue per customer id

# %% [markdown]
# <h4> 2.1) Recency </h4>

# %% [markdown]
# - Add "recency" column, indicating number of days since the last tranasaction date

# %%
# Create "max_date" column for latest transaction date
commerce['max_date'] = max(commerce['invoice_datetime'])
commerce['max_date'] = pd.to_datetime(commerce['max_date'])

# Add "recency" column
commerce['recency'] = (commerce['max_date'] - commerce ['invoice_datetime']).dt.days

# %%
commerce.head(2)
# Out:
#   invoice_no  product_id  quantity  unit_price  total_sale customer_id  \
# 0   78536597  B07GWKDLGT         4      496.95     1987.80       18011
# 1   78536597  B01MTLH408         4       39.99      159.96       18011
#
#    rating  review_count  country  \
# 0     4.6          1399  Germany
# 1     4.6           289  Germany
#
#                                         product_name  ... stock_code  \
# 0  Nikon D3500 W/ AF-P DX NIKKOR 18-55mm f/3.5-5....  ...      21703
# 1  Manfrotto Element Aluminum 5-Section Monopod, ...  ...      40001
#
#      invoice_datetime day_of_week  month  hour  year  quarter  invoice_date  \
# 0 2018-12-01 17:00:00           5     12    17  2018        4    2018-12-01
# 1 2018-12-01 17:00:00           5     12    17  2018        4    2018-12-01
#
#              max_date recency
# 0 2019-12-09 12:00:00     372
# 1 2019-12-09 12:00:00     372
#
# [2 rows x 21 columns]

# %% [markdown]
# <h4> 2.2) Frequency and total revenue </h4>
#
# - Group by and add 'frequency' and 'total_rev' columns

# %%
rfm = commerce.groupby('customer_id').agg({'invoice_no': 'nunique', 'total_sale':'sum', 'recency': 'min'}).reset_index().rename(columns = {'invoice_no': 'frequency', 'total_sale':'total_rev'})
rfm
# Out:
#      customer_id  frequency   total_rev  recency
# 0          12346          1  4433604.10      325
# 1          12347          7   210263.69        1
# 2          12348          4   174939.60       74
# 3          12349          1    42183.30       18
# 4          12350          1    17937.80      309
# ...          ...        ...         ...      ...
# 4334       18280          1     6720.42      277
# 4335       18281          1     2713.22      180
# 4336       18282          2     3304.10        7
# 4337       18283         16   112986.22        3
# 4338       18287          3   119838.50       42
#
# [4339 rows x 4 columns]

# %% [markdown]
# <h3> 3) Remove outliers </h3>

# %% [markdown]
# - Visualise outliers for all three features using boxplot

# %%
# Outlier Analysis of Amount Frequency and Recency
attributes = ['total_rev','frequency','recency']

plt.rcParams['figure.figsize'] = [8,6]
sns.boxplot(data = rfm[attributes], orient="v", palette="Set2" ,whis=1.5, saturation=1, width=0.7)
plt.title("Outliers Variable Distribution", fontsize = 14, fontweight = 'bold')
plt.ylabel("Range", fontweight = 'bold')
plt.xlabel("Attributes", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Attributes')

# %% [markdown]
# - Remove statistical outliers

# %%
# Remove statistical outliers for each variable

# total_rev
q1 = rfm['total_rev'].quantile(0.05)
q3 = rfm['total_rev'].quantile(0.95)
iqr = q3 - q1
rfm = rfm[(rfm['total_rev'] >= q1 - 1.5*iqr) & (rfm['total_rev'] <= q3 + 1.5*iqr)]

# frequency
q1 = rfm['frequency'].quantile(0.05)
q3 = rfm['frequency'].quantile(0.95)
iqr = q3 - q1
rfm = rfm[(rfm['frequency'] >= q1 - 1.5*iqr) & (rfm['frequency'] <= q3 + 1.5*iqr)]

# recency
q1 = rfm['recency'].quantile(0.05)
q3 = rfm['recency'].quantile(0.95)
iqr = q3 - q1
rfm = rfm[(rfm['recency'] >= q1 - 1.5*iqr) & (rfm['recency'] <= q3 + 1.5*iqr)]

rfm.shape
# Out:
# (4257, 4)

# %% [markdown]
# <h3> 4) Scale the features </h3>

# %%
# Scale the features

rfm_df = rfm[['total_rev', 'frequency', 'recency']]

scaler = StandardScaler()

scaler.fit(rfm_df)
rfm_df_scaled = scaler.transform(rfm_df)

rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
rfm_df_scaled.columns = ['total_rev', 'frequency', 'recency']
rfm_df_scaled
# Out:
#       total_rev  frequency   recency
# 0      1.180403   0.858150 -0.917646
# 1      0.862194   0.090898 -0.188702
# 2     -0.333710  -0.676355 -0.747892
# 3     -0.552120  -0.676355  2.157897
# 4     -0.081708   1.113901 -0.578138
# ...         ...        ...       ...
# 4252  -0.653169  -0.676355  1.838360
# 4253  -0.689267  -0.676355  0.869764
# 4254  -0.683944  -0.420604 -0.857733
# 4255   0.304102   3.159909 -0.897675
# 4256   0.365829  -0.164853 -0.508239
#
# [4257 rows x 3 columns]

# %% [markdown]
# <h3> 5) Optimise number of clusters </h3>

# %% [markdown]
# <h4> 5.1) Elbow method with inertia </h4>
#
# - We use inertia as the metric
# - Inertia is the sum of the squared distances of the samples to their closest cluster centroid

# %%
# initialise list of the sum of squared distances (inertia)
ssd = []
# list of number of clusters to try
k_vals = [2,3,4,5,6,7,8,9]

# compute and store inertia for every choice of k
for k_val in k_vals:
    kmeans = KMeans(n_clusters = k_val, max_iter = 50)
    kmeans.fit(rfm_df_scaled)
    ssd.append(kmeans.inertia_)

fig, ax = plt.subplots(1,1)
ax.set_title('Inertia vs number of clusters')
ax.plot(ssd)
ax.set_xlabel('Number of clusters (k)')
ax.set_xticks(ticks = list(range(len(k_vals))))
ax.set_xticklabels(labels = k_vals)
ax.set_ylabel ('Inertia (sum of squared distances)')
plt.show()

# %% [markdown]
# - Not very auspicious. There is no elbow. Inertia just keeps decreasing as we increase k, suggesting the customers don't really lend themselves to any kind of clustering.

# %% [markdown]
# <h4> 5.2) Using silhouette score as metric </h3>

# %% [markdown]
# - Tutorial for creating silhouette plots:
# - https://towardsdatascience.com/silhouette-method-better-than-elbow-method-to-find-optimal-clusters-378d62ff6891

# %% [markdown]
# - The silhouette coefficient for a sample measures its similarity to its own cluster (cohesion) compared to other clusters (separation)
# - Value ranges from (-1, 1)
# - Values close to -1 suggest assignment to wrong cluster
# - Values close to 0 suggest proximity to decision boundary
# - Values close to 1 suggest assignment to correct cluster <br><br>
# - We average the silhouette score for all samples for each k value. We hope to see a peak at a particular k value.

# %%
k_vals = [2,3,4,5,6,7,8,9]
silhouette_avgs = []

for k_val in k_vals:
    kmeans = KMeans(n_clusters = k_val, max_iter = 50)
    kmeans.fit(rfm_df_scaled)
    
    cluster_labels = kmeans.labels_
    silhouette_avg = silhouette_score(rfm_df_scaled, cluster_labels)
    silhouette_avgs.append(silhouette_avg)
    print(f'For {k_val} clusters, silhouette score is {silhouette_avg}')
# Out:
# For 2 clusters, silhouette score is 0.5254872458545418
# For 3 clusters, silhouette score is 0.5007543411121398
# For 4 clusters, silhouette score is 0.4823844816821499
# For 5 clusters, silhouette score is 0.4498175237702174
# For 6 clusters, silhouette score is 0.4075793122514637
# For 7 clusters, silhouette score is 0.4089354911946906
# For 8 clusters, silhouette score is 0.39838458943362887
# For 9 clusters, silhouette score is 0.37573536240507555

# %%
fig, ax = plt.subplots(figsize = (4,4))
ax.set_title('silhouette score vs k value')
ax.plot(k_vals, silhouette_avgs)
ax.set_xlabel('k')
ax.set_ylabel('silhouette score')
plt.show()

# %% [markdown]
# - Again, very inauspicious. There is no peak in silhouette score. On the contrary, it falls continuously.

# %%
range_n_clusters = [2, 3, 4, 5, 6]
silhouette_avg_n_clusters = []

for n_clusters in range_n_clusters:
    fig, ax = plt.subplots(1,1, figsize = (5,10))

    ax.set_xlim([-0.1, 1])
    ax.set_ylim([0, len(rfm_df_scaled) + (n_clusters + 1) * 10])

    clusterer = KMeans(n_clusters = n_clusters)
    cluster_labels = clusterer.fit_predict(rfm_df_scaled)

    silhouette_avg = silhouette_score(rfm_df_scaled, cluster_labels)

    # Compute silhouette score for each sample
    sample_silhouette_values = silhouette_samples(rfm_df_scaled, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]           # Check how the indexing in silhouette_samples works
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10  # 10 for the 0 samples
    
    ax.set_title("The silhouette plot for the various clusters.")
    ax.set_xlabel("The silhouette coefficient values")
    ax.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax.set_yticks([])  # Clear the yaxis labels / ticks
    ax.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

# %% [markdown]
# - All plots show wildly varying thicknesses.
# - For all k values, there are always plots that have a negative silhouette score, and there are always plots where all points fall below the average silhouete score.

# %% [markdown]
# <h3> 6) Clustering with just two features </h3>
#
# - We saw that the clustering worked very poorly when we used the features "total_rev", "frequency", "recency"
# - Now try using just "total_rev" and "frequency"
# - This way, we can also create scatter plots to actually visualise if clustering makes sense.

# %% [markdown]
# <h4> 6.1) Remove outliers, scale features </h4>

# %%
# Create new copy of df
rfm = commerce.groupby('customer_id').agg({'invoice_no': 'nunique', 'total_sale':'sum'}).reset_index().rename(columns = {'invoice_no': 'frequency', 'total_sale':'total_rev'})

# Remove statistical outliers for each variable

# total_rev
q1 = rfm['total_rev'].quantile(0.05)
q3 = rfm['total_rev'].quantile(0.95)
iqr = q3 - q1
rfm = rfm[(rfm['total_rev'] >= q1 - 1.5*iqr) & (rfm['total_rev'] <= q3 + 1.5*iqr)]

# frequency
q1 = rfm['frequency'].quantile(0.05)
q3 = rfm['frequency'].quantile(0.95)
iqr = q3 - q1
rfm = rfm[(rfm['frequency'] >= q1 - 1.5*iqr) & (rfm['frequency'] <= q3 + 1.5*iqr)]

# Scale the features

rfm_df = rfm[['total_rev', 'frequency']]
scaler = StandardScaler()
scaler.fit(rfm_df)
rfm_df_scaled = scaler.transform(rfm_df)
rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
rfm_df_scaled.columns = ['total_rev', 'frequency']

# %% [markdown]
# <h4> 6.2) Plot inertia for different k values </h4>

# %%
# initialise list of the sum of squared distances (inertia)
ssd = []
k_vals = [2,3,4,5,6,7,8,9]

for k_val in k_vals:
    kmeans = KMeans(n_clusters = k_val, max_iter = 50)
    kmeans.fit(rfm_df_scaled)
    ssd.append(kmeans.inertia_)

fig, ax = plt.subplots(1,1, figsize = (4,4))
ax.set_title('Inertia vs number of clusters')
ax.plot(ssd)
ax.set_xlabel('Number of clusters (k)')
ax.set_xticks(ticks = list(range(len(k_vals))))
ax.set_xticklabels(labels = k_vals)
ax.set_ylabel ('Inertia (sum of squared distances)')
plt.show()

# %% [markdown]
# <h4> 6.3) Silhouette Plots and Scatter Plots </h4>
#
# - This time we also create scatter plots for each k-value to see if we actual see clusters

# %%
range_n_clusters = [2, 3, 4, 5, 6, 7]
silhouette_avg_n_clusters = []

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(rfm_df_scaled) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = clusterer.fit_predict(rfm_df_scaled)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(rfm_df_scaled, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    silhouette_avg_n_clusters.append(silhouette_avg)
    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(rfm_df_scaled, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(rfm_df_scaled.iloc[:,0], rfm_df_scaled.iloc[:,1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.7041449496469252
# For n_clusters = 3 The average silhouette_score is : 0.6032484503549403
# For n_clusters = 4 The average silhouette_score is : 0.5414982352619635
# For n_clusters = 5 The average silhouette_score is : 0.548925546476605
# For n_clusters = 6 The average silhouette_score is : 0.5168254793030288
# For n_clusters = 7 The average silhouette_score is : 0.4922746265219153

# %% [markdown]
# - We don't see any real clustering in any of the scatter plots.
# - In fact, the decision boundaries look completely random.
# - This chimes with the fact that the data set was synthesised.
# - There is no underlying pattern reflecting real-life behavioural differences.
